# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.array([1,2,3,4])
y = np.array([5,10,15,20])
plt.scatter(x,y)
x = np.array([1,2,3,4])
y = np.array([5.5,10.5,15.5,20.5])
plt.scatter(x,y)
plt.show()
